# %%
cd C:\Users\mgratale\Desktop\BT\samples\NDsample
# Out:
# C:\Users\mgratale\Desktop\BT\sample

# %%
import numpy as np
import pandas as pd
import MySQLdb as mdb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lr = linear_model.LinearRegression()

# %%
num=10000
m=10
c=400
nos=40

# %%
noise=np.random.normal(0,nos,num)

# %%
noise.shape
# Out:
# (10000L,)

# %%
h,b=np.histogram(noise,bins=20)

# %%
plt.plot(b[0:20],h,'o')

# %%
x=np.random.uniform(10,100,num)

# %%
y=(m*x+c)+noise

# %%
plt.plot(x,y,'o')

# %%
data=np.vstack((x,y))

# %%
data.shape
# Out:
# (2L, 10000L)

# %%
from sklearn.cross_validation import cross_val_predict
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
xtrain=np.reshape(xtrain,(len(xtrain),1))
xtest=np.reshape(xtest,(len(xtest),1))

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((8000L, 1L), (2000L, 1L), (8000L,), (2000L,))

# %%
model=linear_model.LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = model.predict(xtest)

# %%
mean_squared_error(predictions, ytest)
# Out:
# 1540.4823367011352

# %%
model.coef_,model.intercept_
# Out:
# (array([ 10.00482614]), 400.33403042366831)

# %%
plt.plot(ytest,predictions,'o')

# %%
plt.plot(xtest,ytest,'o')
plt.plot(xtest,predictions)
